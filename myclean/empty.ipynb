# %% [markdown]
# <a href="https://colab.research.google.com/github/mail2venkie/fastbook/blob/temp/myclean/empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Configure Kaggle connectivity

# %%
def kaggle_auth():
  # !cp /content/gdrive/MyDrive/kaggle/kaggle.sh /content/
  # !sh /content/kaggle.sh

# %%
def kaggle_download(competition):
  # !mkdir /content/{competition}
  # !kaggle competitions download -c '{competition}'
  # !mv {competition}.zip /content/{competition}
  # !unzip /content/{competition}/{competition}.zip -d /content/{competition}

# %%
kaggle_auth()
